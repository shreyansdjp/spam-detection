# %%
import pandas as pd
import re

# %%
df = pd.read_csv('./data/spam.csv', encoding='latin-1')
df.describe()
# Out:
#           v1                      v2  \
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30
#
#                                                Unnamed: 2  \
# count                                                  50
# unique                                                 43
# top      bt not his girlfrnd... G o o d n i g h t . . .@"
# freq                                                    3
#
#                    Unnamed: 3 Unnamed: 4
# count                      12          6
# unique                     10          5
# top      MK17 92H. 450Ppw 16"    GNT:-)"
# freq                        2          2

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1, inplace=True)
df.rename(columns={'v1': 'label', 'v2': 'text'}, inplace=True)
df.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.replace({'label': {'ham': 0, 'spam': 1}}, inplace=True)
df['text'] = df['text'].str.lower()
df.head()
# Out:
#   label                                               text
# 0     0  go until jurong point, crazy.. available only ...
# 1     0                      ok lar... joking wif u oni...
# 2     1  free entry in 2 a wkly comp to win fa cup fina...
# 3     0  u dun say so early hor... u c already then say...
# 4     0  nah i don't think he goes to usf, he lives aro...

# %%
def remove_url(text):
    new_text = re.sub(r'(?:https?://|http//|www\.|wap\.|\.wml\b|\.com\b|\.co\b|\.tv\b|\.ac\b)', '', text)
    new_text = re.sub(r'(lt|gt|amp|quot|#39|#34|nbsp|&lt|&gt|&amp|&quot|&#39|&#34|&nbsp)', '', new_text)
    return new_text

df['text'] = df['text'].apply(remove_url)
df.head()
# Out:
#   label                                               text
# 0     0  go until jurong point, crazy.. available only ...
# 1     0                      ok lar... joking wif u oni...
# 2     1  free entry in 2 a wkly comp to win fa cup fina...
# 3     0  u dun say so early hor... u c already then say...
# 4     0  nah i don't think he goes to usf, he lives aro...

# %%
df['text'] = df['text'].str.replace(r'\d{4,10}', '', regex=True)
df['text'] = df['text'].str.replace(r'to\s\d{4,}', '', regex=True)
df.head()
# Out:
#   label                                               text
# 0     0  go until jurong point, crazy.. available only ...
# 1     0                      ok lar... joking wif u oni...
# 2     1  free entry in 2 a wkly comp to win fa cup fina...
# 3     0  u dun say so early hor... u c already then say...
# 4     0  nah i don't think he goes to usf, he lives aro...

# %%
df['text'] = df['text'].str.replace(r'[^A-Za-z0-9]', ' ', regex=True)
df['text'] = df['text'].str.replace(r'\s+', ' ', regex=True)
df['text'] = df['text'].str.strip()
df.head()
# Out:
#   label                                               text
# 0     0  go until jurong point crazy available only in ...
# 1     0                            ok lar joking wif u oni
# 2     1  free entry in 2 a wkly comp to win fa cup fina...
# 3     0        u dun say so early hor u c already then say
# 4     0  nah i don t think he goes to usf he lives arou...

# %%
df.to_csv('./data/spam_preprocessed.csv', index=False)
